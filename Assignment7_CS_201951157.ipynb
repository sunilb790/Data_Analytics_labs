# %% [markdown]
# Lab Assignment 7
# SUNIL BHENSPALIYA
# **ID  :-201951157**

# %%
import pandas as pd
import seaborn as sns
import math
import matplotlib.pyplot as plt
import numpy as np

# %% [markdown]
# ASSIGNMENT TASK :- 1

# %%
df_1=pd.read_csv(r"/content/sample_data/All_India_CPI.csv")
df_1 = df_1.fillna(0)
df_1.fillna(0, inplace=True)
df_1.iat[315,20]=0
df_1.iat[291,20]=0
df_1.iat[294,20]=0
df_1['Housing'] = df_1.Housing.astype(float)
df_1_2=df_1.iloc[:, 3:28]
df_1_2
df_1_2.corr()
sns.heatmap(df_1_2.corr())

# %% [markdown]
# ASSIGNMENT TASK :- 2

# %%
df_2=pd.read_csv(r"/content/sample_data/IPL Matches 2008-2020.csv")
df_2= df_2.fillna(0)
df_2.fillna(0, inplace=True)
df_2
df_2_crosstab=pd.crosstab(df_2['toss_winner'],
            df_2['winner'], 
            margins = False)
df_2_crosstab
# Out:
# winner                       0  Chennai Super Kings  Deccan Chargers  \
# toss_winner
# Chennai Super Kings          0                   61                1
# Deccan Chargers              0                    2               19
# Delhi Capitals               0                    2                0
# Delhi Daredevils             1                    5                0
# Gujarat Lions                0                    0                0
# Kings XI Punjab              0                    4                2
# Kochi Tuskers Kerala         0                    0                1
# Kolkata Knight Riders        0                    6                1
# Mumbai Indians               0                    5                0
# Pune Warriors                0                    3                0
# Rajasthan Royals             2                   10                1
# Rising Pune Supergiant       0                    0                0
# ...

# %% [markdown]
# ASSIGNMENT TASK :- 3

# %%
df_3=pd.read_csv(r"/content/sample_data/melb_data.csv")
df_3= df_3.fillna(0)
df_3.fillna(0, inplace=True)

# %%
# find the maximum of each column
maxValues = df_3["Price"].max()
print(maxValues)
maxValues = df_3["Landsize"].max()
print(maxValues)
# Out:
# 9000000.0
# 433014.0

# %%
data1="Landsize"
data2="Price"
hb=plt.hexbin(df_3[data1], 
           df_3[data2], 
            gridsize = 10,
           cmap ='Greens') 
plt.xlabel(data1)
plt.ylabel(data2)
cb = plt.colorbar(hb)
plt.show()

# %%
sns.kdeplot(data=df_3, x=data1, y=data2,fill=True,levels=5)
plt.xlabel(data1)
plt.ylabel(data2)
plt.show()
